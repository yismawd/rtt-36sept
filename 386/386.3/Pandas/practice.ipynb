# %% [markdown]
# Student information intial look
# ## import libraries
# # load the data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/RTT_36_data.csv')

# %%
rows, cols = df.shape

# %%
df.head()
df.tail()

# %%
df.describe()

# %%
df.info()
