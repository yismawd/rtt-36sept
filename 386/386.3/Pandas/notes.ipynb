# %% [markdown]
# Pandas Notes

# %%
try:
    import pandas as pd
except ModuleNotFoundError:
    import subprocess, sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas"])
    import pandas as pd
import numpy as np
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 47.6 MB/s  0:00:00eta 0:00:01
# ...

# %%
# declare series
ser = pd.Series(list('abcdefghijklmnopqrstuvwxyz'))

# Give it a name attribute
ser.name = 'alphabet'

print(ser)

# %%
# .head(n) - show top 5 records - n- number of records
print(ser.head())

# %%
# .tail(n) - shop the bottom 5 records - n- number of records
print(ser.tail())

# %%
# declare a series from a dictionary
d = {
    'a': 0.0,
    'b': 1.0,
    'c': 2.0
}

# for a dictionary becoming a series, the keys become the indexes
float_series = pd.Series(d)
print(float_series)

# %%
# Index is specified, corresponding data will be pulled into the series
customer_index = pd.Series(d, index=['a', 'y', 'x'])

print(customer_index)

# %%
carlories = {
    'day1': 2200,
    'day2': 2500,
    'day3': 2700,
}

# create a series with the following dictionary, but only with days 1 and 2


index = ['day1', 'day2']
calories_series = pd.Series(carlories, index=index)
print(scalar_series)

# %%
# Series of scalar value. Each index will have the same value
scalar_series = pd.Series(5.0, index=['a', 'b', 'c', 'd', 'e'])

print(scalar_series)

# %%
# element wise arithmetic with series
ser1 = pd.Series([2, 4, 6, 8, 10])
ser2 = pd.Series([1, 3, 5, 7, 9])

print("Addition:\n", ser1 + ser2)
print("Subtraction:\n", ser1 - ser2)
print("Multiplication:\n", ser1 * ser2)
print("Division:\n", ser1 / ser2)
# Out:
# Addition:
#  0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64
# Subtraction:
#  0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64
# Multiplication:
#  0     2
# 1    12
# 2    30
# 3    56
# 4    90
# dtype: int64
# Division:
#  0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.111111
# dtype: float64
