# %%
from numpy import random

# %%
# Generate a random array of 10 numbers between 0-1
data = random.rand(10)

print(data)
# Out:
# [0.55449983 0.68990682 0.53857831 0.70396609 0.96727514 0.61063608
#  0.51197693 0.46493893 0.74434585 0.23679445]

# %% [markdown]
# # GLAB_386.2.1 - Random w/Numpy

# %%
# Generate an array of random numbers with a normal distribution -1 to 1
# average 0
# standard deviation 1

normal_dist = random.randn(10)

print(normal_dist)
# Out:
# [-1.56828119 -0.03013081 -0.08668032  0.59325953  0.07122027 -1.93223216
#  -0.51243965  1.2217757   0.05771014  0.49831126]

# %%
# Normally distributed Matrix, 3 rows, 2 records in each row
normal_dist_matrix = random.randn(3, 2)

print(normal_dist_matrix)
# Out:
# [[ 1.25423211  0.54027076]
#  [ 1.25436035 -0.46882798]
#  [-0.28034448 -1.55070215]]

# %%
# define a list
elements = ['a', 'b', 'c', 'd', 'e', 'f']
# choose a random value from the list
random_sample = random.choice(elements)
print(random_sample)
# Out:
# e

# %%
print('Before Shuffle', elements)
random.shuffle(elements)
print('After Shuffle', elements) # shuffling elements of array for randomness
# Out:
# Before Shuffle ['a', 'b', 'c', 'd', 'e', 'f']
# After Shuffle ['b', 'e', 'd', 'c', 'f', 'a']
